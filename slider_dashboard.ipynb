# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
import matplotlib
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider, HoverTool
from bokeh.plotting import Figure, output_file, show,output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d828ba30-e8f6-4a92-996a-2533b93ba82e">Loading BokehJS ...</span>
#     </div>

# %%
dataframe_2015=pd.read_csv("2015.csv")
dataframe_2015['Year']=2015
dataframe_2016=pd.read_csv("2016.csv")
dataframe_2016['Year']=2016

dataframe_2015.set_index('Year',inplace=True)
dataframe_2016.set_index('Year',inplace=True)

# %%
data_f=pd.concat([dataframe_2015[1:100],dataframe_2016[1:100]],axis=0)
#data_f=pd.concat([dataframe_2015,dataframe_2016],axis=0)
data_f = data_f.sample(frac=1)
#data_f = data_f.sample(frac=1)

# %%
data_f.head()
# Out:
#              Country  Dystopia Residual  Economy (GDP per Capita)   Family  \
# Year
# 2016  United Kingdom            2.14999                   1.40283  1.08672
# 2015         Belgium            2.41484                   1.30782  1.28566
# 2016       Macedonia            2.08947                   1.01930  0.78236
# 2015       Guatemala            2.74255                   0.74553  1.04356
# 2015         Algeria            2.43209                   0.93929  1.07772
#
#       Freedom  Generosity  Happiness Rank  Happiness Score  \
# Year
# 2016  0.50036     0.50156              23            6.725
# 2015  0.58450     0.22250              19            6.937
# 2016  0.27668     0.23507              95            5.121
# 2015  0.57733     0.27489              43            6.123
# 2015  0.28579     0.07822              68            5.605
#
#       Health (Life Expectancy)  Lower Confidence Interval  \
# Year
# 2016                   0.80991                      6.647
# 2015                   0.89667                        NaN
# 2016                   0.64738                      5.017
# 2015                   0.64425                        NaN
# 2015                   0.61766                        NaN
#
#                                Region  Standard Error  \
# Year
# 2016                   Western Europe             NaN
# 2015                   Western Europe         0.03595
# 2016       Central and Eastern Europe             NaN
# 2015      Latin America and Caribbean         0.05224
# 2015  Middle East and Northern Africa         0.05099
#
#       Trust (Government Corruption)  Upper Confidence Interval
# Year
# 2016                        0.27399                      6.803
# 2015                        0.22540                        NaN
# 2016                        0.07047                      5.225
# 2015                        0.09472                        NaN
# 2015                        0.17383                        NaN

# %%
data_f.columns = data_f.columns.str.replace('\s+', '_') 
data_f.columns = data_f.columns.str.replace('(', '') 
data_f.columns = data_f.columns.str.replace(')', '') 
data_f.columns
data=data_f
data.drop('Dystopia_Residual',axis=1,inplace=True)
data.head(5)
# Out:
#              Country  Economy_GDP_per_Capita   Family  Freedom  Generosity  \
# Year
# 2016  United Kingdom                 1.40283  1.08672  0.50036     0.50156
# 2015         Belgium                 1.30782  1.28566  0.58450     0.22250
# 2016       Macedonia                 1.01930  0.78236  0.27668     0.23507
# 2015       Guatemala                 0.74553  1.04356  0.57733     0.27489
# 2015         Algeria                 0.93929  1.07772  0.28579     0.07822
#
#       Happiness_Rank  Happiness_Score  Health_Life_Expectancy  \
# Year
# 2016              23            6.725                 0.80991
# 2015              19            6.937                 0.89667
# 2016              95            5.121                 0.64738
# 2015              43            6.123                 0.64425
# 2015              68            5.605                 0.61766
#
#       Lower_Confidence_Interval                           Region  \
# Year
# 2016                      6.647                   Western Europe
# 2015                        NaN                   Western Europe
# 2016                      5.017       Central and Eastern Europe
# 2015                        NaN      Latin America and Caribbean
# 2015                        NaN  Middle East and Northern Africa
#
#       Standard_Error  Trust_Government_Corruption  Upper_Confidence_Interval
# Year
# 2016             NaN                      0.27399                      6.803
# 2015         0.03595                      0.22540                        NaN
# 2016             NaN                      0.07047                      5.225
# 2015         0.05224                      0.09472                        NaN
# 2015         0.05099                      0.17383                        NaN

# %%
source=ColumnDataSource(dict(
x=data.loc[2015].Happiness_Rank,
y=data.loc[2015].Economy_GDP_per_Capita,
country=data.loc[2015].Country,
region=data.loc[2015].Region,
))

plot = Figure(plot_width=900, plot_height=700,
              tools=[HoverTool(tooltips='@country',show_arrow=False)],
              x_axis_label='Happiness Rank',y_axis_label='Economy GDP per Capita')


regions_list = (data.Region.unique()).tolist()

# Import CategoricalColorMapper from bokeh.models 
# and the Spectral6 palette from bokeh.palettes
from bokeh.models import CategoricalColorMapper
from bokeh.palettes import Spectral10

# Make a color mapper: color_mapper
color_mapper = CategoricalColorMapper(factors=regions_list, 
                                      palette=Spectral10)

# Add the color mapper to the circle glyph
plot.circle(x='x', y='y', fill_alpha=5, source=source,
            color=dict(field='region',transform=color_mapper), 
            legend='region')
plot.legend.location = 'bottom_right'

# %%
from bokeh.io import push_notebook

def update_plot(year):
    
    new_data=dict(
        x=data.loc[year].Happiness_Rank,
        y=data.loc[year].Economy_GDP_per_Capita,
        country=data.loc[year].Country,
        region=data.loc[year].Region,
    )
    source.data=new_data
    push_notebook()

# %%
from ipywidgets import interact
interact(update_plot,year=(2015,2016,1))
show(plot,notebook_handle=True)
output_file("jj.html")
# Out:
# interactive(children=(IntSlider(value=2015, description='year', max=2016, min=2015), Output()), _dom_classes=('widget-interact',))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d29f33b9-55c0-43ca-9e14-61658586e65e"></div>
# </div>

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Slider

output_file("slider.html")

slider = Slider(start=0, end=10, value=1, step=.1, title="Slider",bar_color="blue")

show(widgetbox(slider))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a339884f-4a74-472e-82e9-f9bc896ac040"></div>
# </div>
